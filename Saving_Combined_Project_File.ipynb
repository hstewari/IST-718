# %%
import os
import glob
import pandas as pd
os.getcwd()
pd.options.display.max_columns = 65
pd.options.display.max_rows = 13000000
print(pd.options.display.max_rows)
# Out:
# 13000000

# %%
extension = 'csv'
all_filenames = [i for i in glob.glob('*.{}'.format(extension))]

# %%
#combine all files in the list
combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames ], ignore_index = True)
#combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames ])
# Out:
# C:\Users\yz339c\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3185: DtypeWarning: Columns (43) have mixed types. Specify dtype option on import or set low_memory=False.
#   if (yield from self.run_code(code, result)):

# %%
combined_csv.head()
combined_csv.shape
# Out:
# (12771253, 60)

# %%
#export to csv
combined_csv.to_csv( "combined_csv.csv", index=False, encoding='utf-8-sig')

# %%
combined_csv.to_pickle('OTP_11.17.19.pkl')  #to save the dataframe, combined csv to OTP_11.17.19.pkl
#OTP - ON time performance downloaded on  11.17.19

'''
#To load pickle data
df = pd.read_pickle('OTP_11.17.19.pkl')
# to load 1OTP_11.17.19.pkl back to the dataframe df
'''
# Out:
# "\n#To load pickle data\ndf = pd.read_pickle('OTP_11.17.19.pkl')\n# to load 1OTP_11.17.19.pkl back to the dataframe df\n"

# %%
'''
import feather
# %time feather.write_dataframe(combined_csv, 'feather.OTP_11.17.19')
####
pip install fastparquet
from fastparquet import write 
write('outfile.parq', df)
OR
df.to_parquet('df.parquet.gzip', compression='gzip')
pd.read_parquet('df.parquet.gzip')

OR
import pyarrow as pa
import pyarrow.parquet as pq

df = pd.DataFrame(data={'col1': [1, 2], 'col2': [3, 4]})
table = pa.Table.from_pandas(df, preserve_index=True)
pq.write_table(table, 'output.parquet')
'''
# Out:
# "\nimport feather\n%time feather.write_dataframe(combined_csv, 'feather.OTP_11.17.19')\n####\npip install fastparquet\nfrom fastparquet import write \nwrite('outfile.parq', df)\nOR\ndf.to_parquet('df.parquet.gzip', compression='gzip')\npd.read_parquet('df.parquet.gzip')\n\nOR\nimport pyarrow as pa\nimport pyarrow.parquet as pq\n\ndf = pd.DataFrame(data={'col1': [1, 2], 'col2': [3, 4]})\ntable = pa.Table.from_pandas(df, preserve_index=True)\npq.write_table(table, 'output.parquet')\n"

# %%
combined_csv.tail()
# Out:
#           YEAR  QUARTER  MONTH  DAY_OF_MONTH  DAY_OF_WEEK     FL_DATE  \
# 12771248  2018        3      9             7            5  2018-09-07
# 12771249  2018        3      9             7            5  2018-09-07
# 12771250  2018        3      9             7            5  2018-09-07
# 12771251  2018        3      9             7            5  2018-09-07
# 12771252  2018        3      9             7            5  2018-09-07
#
#          OP_UNIQUE_CARRIER  OP_CARRIER_AIRLINE_ID OP_CARRIER  \
# 12771248                UA                  19977         UA
# 12771249                UA                  19977         UA
# 12771250                UA                  19977         UA
# 12771251                UA                  19977         UA
# 12771252                UA                  19977         UA
#
#           OP_CARRIER_FL_NUM  ORIGIN_AIRPORT_ID  ORIGIN_AIRPORT_SEQ_ID  \
# 12771248               2298              13198                1319801
# ...
